# %%
import matplotlib.pyplot as plt
import pandas as pd
import import_ipynb
import kinect
import cv2
import numpy as np
from scipy.signal import find_peaks

# %%
dir_path = "D:\\HK_PS4_Data to Xuan & Junjie\\Kinect_Sensor_data"
imu_file_path = "E:\\JupyterLab\\TUG\\IMU_time.xlsx"

# %%
kinect_files_path = kinect.get_file_path(dir_path)

# %%
# for i in range(20):
spmid_diff_dict = {}
for i in range(len(kinect_files_path)):
    kinect_data = kinect.Kinect(pd.read_csv(kinect_files_path[i]))

    spmid_x = kinect_data.get_xyz_tolist()[1][0]
    spmid_y = kinect_data.get_xyz_tolist()[1][1]
    
    spmid_x_diff = [spmid_x[i+1]-spmid_x[i] for i in range(len(spmid_x)-1)]
    spmid_y_diff = [spmid_y[i+1]-spmid_y[i] for i in range(len(spmid_y)-1)]
    time_stamp = kinect_data.get_timestamp()[:-1]
    
    tps_dict = kinect.kin_imutps_dict(imu_file_path, kinect_files_path)
    w_s, t_s, t_e, w_e = kinect.imu2kin_nrest_spltpts(kinect_files_path[i], tps_dict)
    
    '''
    fst_walk_x = spmid_x_diff[w_s:t_s].copy()
    sec_walk_x = spmid_x_diff[t_e:w_e].copy()
    fst_walk_y = spmid_y_diff[w_s:t_s].copy()
    sec_walk_y = spmid_y_diff[t_e:w_e].copy()
    
    x = np.abs(fst_walk_x+sec_walk_x)
    y = np.abs(fst_walk_y+sec_walk_y)
    
    mean_x = np.mean(x)
    var_x = np.var(x)
    
    mean_y = np.mean(y)
    var_y = np.var(y)
    
    centre_name, test_id, test_date = kinect.get_test_info(kinect_files_path[i])
    spmid_diff_dict[kinect_files_path[i]] = [centre_name, test_id, test_date, mean_x, var_x, mean_y, var_y]
    
    columns = pd.DataFrame(['centre_name', 'test_id', 'test_date', 'mean_x', 'var_x', 'mean_y', 'var_y'])
    df = pd.DataFrame(spmid_diff_dict)
    df_t = pd.DataFrame(df.values.T, index=df.columns, columns=columns)
    df_t.to_excel('./spmid_diff.xlsx')
    '''

    fig = plt.figure(figsize=(10, 10))
    plt.subplot(121)
    plt.plot(time_stamp[w_s:t_s],
             spmid_x_diff[w_s:t_s],
             'r',
             label="spmid_diff_x")
    
    plt.plot(time_stamp[t_e:w_e],
             spmid_x_diff[t_e:w_e],
             'r',
             label="spmid_diff_x")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-0.1, 0.05))

    plt.xlabel("time")
    plt.ylabel("x")
    plt.title('x  '+str(i+1))
    plt.legend()

    plt.subplot(122)
    plt.plot(time_stamp[w_s:t_s],
             spmid_y_diff[w_s:t_s],
             'b',
             label="spmid_diff_y")

    plt.plot(time_stamp[t_e:w_e],
             spmid_y_diff[t_e:w_e],
             'b',
             label="spmid_diff_y")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-0.1, 0.05))

    plt.xlabel("time")
    plt.ylabel("y")
    plt.title('y  '+str(i+1))
    plt.legend()
    
    plt.show()

# %%
# for i in range(20):
spmid_dict = {}
for i in range(len(kinect_files_path)):
    kinect_data = kinect.Kinect(pd.read_csv(kinect_files_path[i]))

    spmid_x = kinect_data.get_xyz_tolist()[0][0]
    spmid_y = kinect_data.get_xyz_tolist()[0][1]

    time_stamp = kinect_data.get_timestamp()[:-1]
    
    tps_dict = kinect.kin_imutps_dict(imu_file_path, kinect_files_path)
    w_s, t_s, t_e, w_e = kinect.imu2kin_nrest_spltpts(kinect_files_path[i], tps_dict)
    
    '''
    fst_walk_x = spmid_x[w_s:t_s].copy()
    sec_walk_x = spmid_x[t_e:w_e].copy()
    fst_walk_y = spmid_y[w_s:t_s].copy()
    sec_walk_y = spmid_y[t_e:w_e].copy()
    
    x = fst_walk_x+sec_walk_x 
    y = fst_walk_y+sec_walk_y
    
    mean_x = np.mean(x)
    var_x = np.var(x)
    
    mean_y = np.mean(y)
    var_y = np.var(y)
    
    centre_name, test_id, test_date = kinect.get_test_info(kinect_files_path[i])
    spmid_dict[kinect_files_path[i]] = [centre_name, test_id, test_date, mean_x, var_x, mean_y, var_y]
    
    columns = pd.DataFrame(['centre_name', 'test_id', 'test_date', 'mean_x', 'var_x', 'mean_y', 'var_y'])
    df = pd.DataFrame(spmid_dict)
    df_t = pd.DataFrame(df.values.T, index=df.columns, columns=columns)
    df_t.to_excel('./spmid.xlsx')
    '''

    fig = plt.figure(figsize=(10, 10))
    plt.subplot(121)
    plt.plot(time_stamp[w_s:t_s],
             spmid_x[w_s:t_s],
             'r',
             label="spmid_x")
    
    plt.plot(time_stamp[t_e:w_e],
             spmid_x[t_e:w_e],
             'r',
             label="spmid_x")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-2, 2))

    plt.xlabel("time")
    plt.ylabel("x")
    plt.title('x  '+str(i+1))
    plt.legend()

    plt.subplot(122)
    plt.plot(time_stamp[w_s:t_s],
             spmid_y[w_s:t_s],
             'b',
             label="spmid_y")

    plt.plot(time_stamp[t_e:w_e],
             spmid_y[t_e:w_e],
             'b',
             label="spmid_y")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-0.5, 0.5))

    plt.xlabel("time")
    plt.ylabel("y")
    plt.title('y  '+str(i+1))
    plt.legend()
    
    plt.show()

# %%
# for i in range(20):
for i in range(20):
    kinect_data = kinect.Kinect(pd.read_csv(kinect_files_path[i]))

    ankle_left = kinect_data.get_xyz_tolist()[14][1]
    ankle_left = cv2.blur(np.array(ankle_left), (1,3))

    time_stamp = kinect_data.get_timestamp()

    fig = plt.figure(figsize=(10, 10))
    plt.plot(time_stamp,
             ankle_left,
             'r',
             label="ankle_left")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-1, 0))

    plt.xlabel("time")
    plt.ylabel("y")
    plt.title('y  '+str(i+1))
    plt.legend()
    
    plt.show()

# %%
# for i in range(20):
gait_feature_dict = {}
for i in range(len(kinect_files_path)):
    kinect_data = kinect.Kinect(pd.read_csv(kinect_files_path[i]))

    spmid_x = kinect_data.get_xyz_tolist()[1][0]
    spmid_y = kinect_data.get_xyz_tolist()[1][1]
    
    spmid_x_diff = [spmid_x[i+1]-spmid_x[i] for i in range(len(spmid_x)-1)]
    spmid_y_diff = [spmid_y[i+1]-spmid_y[i] for i in range(len(spmid_y)-1)]
    time_stamp = kinect_data.get_timestamp()[:-1]
    
    tps_dict = kinect.kin_imutps_dict(imu_file_path, kinect_files_path)
    w_s, t_s, t_e, w_e = kinect.imu2kin_nrest_spltpts(kinect_files_path[i], tps_dict)
    
    #  寻峰
    fst_walk_peaks, lproperties = find_peaks(np.array(spmid_x_diff[w_s:t_s]).reshape(-1), distance=10)
    sec_walk_peaks, rproperties = find_peaks(np.array(spmid_x_diff[t_e:w_e]).reshape(-1), distance=10)
    
    #  计算行走阶段步数
    gait_num = len(fst_walk_peaks)+len(sec_walk_peaks)
    
    sum_ = 0
    for i in range(len(fst_walk_peaks)):
        sum_ += spmid_x_diff[w_s:t_s][fst_walk_peaks[i]]
    
    for i in range(len(sec_walk_peaks)):
        sum_ += spmid_x_diff[t_e:w_e][sec_walk_peaks[i]]

    average_gait_width = np.round((sum_/gait_num), 2)
    gait_feature_dict[kinect_files_path[i]] = [gait_num, average_gait_width]
    
    '''
    fst_walk_x = spmid_x_diff[w_s:t_s].copy()
    sec_walk_x = spmid_x_diff[t_e:w_e].copy()
    fst_walk_y = spmid_y_diff[w_s:t_s].copy()
    sec_walk_y = spmid_y_diff[t_e:w_e].copy()
    
    x = np.abs(fst_walk_x+sec_walk_x)
    y = np.abs(fst_walk_y+sec_walk_y)
    
    mean_x = np.mean(x)
    var_x = np.var(x)
    
    mean_y = np.mean(y)
    var_y = np.var(y)
    
    centre_name, test_id, test_date = kinect.get_test_info(kinect_files_path[i])
    spmid_diff_dict[kinect_files_path[i]] = [centre_name, test_id, test_date, mean_x, var_x, mean_y, var_y]
    
    columns = pd.DataFrame(['centre_name', 'test_id', 'test_date', 'mean_x', 'var_x', 'mean_y', 'var_y'])
    df = pd.DataFrame(spmid_diff_dict)
    df_t = pd.DataFrame(df.values.T, index=df.columns, columns=columns)
    df_t.to_excel('./spmid_diff.xlsx')

    fig = plt.figure(figsize=(10, 10))
    plt.subplot(121)
    plt.plot(time_stamp[w_s:t_s],
             spmid_x_diff[w_s:t_s],
             'r',
             label="spmid_diff_x")
    
    plt.plot(time_stamp[t_e:w_e],
             spmid_x_diff[t_e:w_e],
             'r',
             label="spmid_diff_x")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-0.1, 0.05))

    plt.xlabel("time")
    plt.ylabel("x")
    plt.title('x  '+str(i+1))
    plt.legend()

    plt.subplot(122)
    plt.plot(time_stamp[w_s:t_s],
             spmid_y_diff[w_s:t_s],
             'b',
             label="spmid_diff_y")

    plt.plot(time_stamp[t_e:w_e],
             spmid_y_diff[t_e:w_e],
             'b',
             label="spmid_diff_y")

    plt.xlim((0, int(kinect_data.get_maxtime())+5))
    plt.ylim((-0.1, 0.05))

    plt.xlabel("time")
    plt.ylabel("y")
    plt.title('y  '+str(i+1))
    plt.legend()
    
    plt.show()
    '''

gait_feature = pd.DataFrame(gait_feature_dict)
gait_feature_t = pd.DataFrame(gait_feature.values.T, index=gait_feature.columns, columns=gait_feature.index)

gait_feature_t.to_csv("./gait__feature.csv")
